% %%
x=[1 2 3 4];
h=[1 -1 1 ];
y=conv(x,h);
disp(y);
% Out:
%      1     1     2     3    -1     4

% %%
subplot(3,1,1);
stem(x);
title('Ibput signal x[n');
subplot(3,1,2);
stem(h);
title('Impluse response h[n]');

subplot(3,1,3);
stem(y);
title('Output signal y[n]=x[n]*h[n]');
% Out:
% <center><img src="data:image/png;base64,..." width="562" alt="figure_0.png"></center>

% %% [markdown]
% !!!EndOutputRegion!!!
